# %% [markdown]
# # **CHAPTER 2. Phylogenomic analysis**

# %% [markdown]
# Import all the modules needed

# %%
import os
import re
import pandas as pd
from Bio import SeqIO

# %% [markdown]
# Create the directory to store the data

# %%
# %%bash
#
# mkdir phylogenomics/
# mkdir phylogenomics/Proteins_renamed

# %% [markdown]
# Take sequences files from `pangenome/Annotation/Proteins_classic` directory and rename them all to `>[GENE]` format

# %%
# %%bash
#
# for file in pangenome/Annotation/Proteins_classic/*.prt
# do
#   sed -E -e 's/^.*(ND1|nd1|NAD1|nad1).*/>NAD1/' \
#          -e 's/^.*(ND2|nd2|NAD2|nad2).*/>NAD2/' \
#          -e 's/^.*(ND3|nd3|NAD3|nad3).*/>NAD3/' \
#          -e 's/^.*(ND4|nd4|NAD4|nad4).*/>NAD4/' \
#          -e 's/^.*(ND4L|nd4l|NAD4L|nad4l|NAD4l|nad4L).*/>NAD4L/' \
#          -e 's/^.*(ND5|nd5|NAD5|nad5).*/>NAD5/' \
#          -e 's/^.*(ND6|nd6|NAD6|nad6).*/>NAD6/' \
#          -e 's/^.*(COX1|cox1).*/>COX1/' \
#          -e 's/^.*(COX2|cox2).*/>COX2/' \
#          -e 's/^.*(COX3|cox3).*/>COX3/' \
#          -e 's/^.*(COB|cob).*/>COB/' \
#          -e 's/^.*(rps3|RPS3).*/>rps3/' \
#          -e 's/^.*(ATP6|atp6).*/>ATP6/' \
#          -e 's/^.*(ATP8|atp8).*/>ATP8/' \
#          -e 's/^.*(ATP9|atp9).*/>ATP9/' \
#          -e 's/^.*(CYTB|cytb).*/>CYTB/' "$file" | \
#   awk '/^>/ {keep=0} /^>(NAD1|NAD2|NAD3|NAD4|NAD4L|NAD5|NAD6|COX1|COX2|COX3|COB|rps3|ATP6|ATP8|ATP9|CYTB)/ {keep=1} keep' \
#   > phylogenomics/Proteins_renamed/$(basename "$file" .prt)_renamed_mt_prot.fa
# done

# %%
! head -1 phylogenomics/Proteins_renamed/NC_015789_renamed_mt_prot.fa
# Out:
# >COX1

# %% [markdown]
# Good.

# %% [markdown]
# Download `BBMap`

# %%
! wget https://sourceforge.net/projects/bbmap/files/latest/download -O BBMap.tar.gz

# %% [markdown]
# Unarchive `BBMap` and delete the initial archive

# %%
! tar -xvzf BBMap.tar.gz && rm -rf BBMap.tar.gz

# %% [markdown]
# Create a directory to store renamed sequences

# %%
! mkdir phylogenomics/Proteins_renamed_r2/

# %% [markdown]
# Using `BBMap` rename sequences from `>[GENE]` format to `>accession_number_[GENE]` format

# %%
# %%bash
#
# for file in phylogenomics/Proteins_renamed/*mt_prot.fa
# do export species_name=$(basename $file _renamed_mt_prot.fa)
# bbmap/rename.sh in=$file prefix="$species_name" addprefix=true out=phylogenomics/Proteins_renamed_r2/$species_name.mt_prots.fa ignorejunk=true ;
# done

# %%
! head -1 phylogenomics/Proteins_renamed_r2/NC_015789.mt_prots.fa
# Out:
# >NC_015789_COX1

# %% [markdown]
# Good.

# %% [markdown]
# Some genes could be not single copy genes. In some organisms there may be several `cox1` genes. That's why we need to enumerate them!

# %%
def rename_sequences(input_dir, output_dir):
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Loop through each FASTA file in the directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".fasta") or filename.endswith(".fa"):
            filepath = os.path.join(input_dir, filename)
            output_filepath = os.path.join(output_dir, filename)

            # Dictionary to keep track of sequence names and their counts
            name_count = {}
            
            # List to store the updated sequences
            updated_sequences = []
            
            # Read the FASTA file
            for record in SeqIO.parse(filepath, "fasta"):
                name = record.id
                
                # If the name is already seen, append a count suffix
                if name in name_count:
                    name_count[name] += 1
                    new_name = f"{name}_{name_count[name]}"
                else:
                    name_count[name] = 1
                    new_name = f"{name}_1"
                
                # Update the record ID
                record.id = new_name
                record.description = ""  # Optionally clear the description
                
                # Store the updated record
                updated_sequences.append(record)

            # Write the updated sequences to a new FASTA file
            with open(output_filepath, "w") as output_handle:
                SeqIO.write(updated_sequences, output_handle, "fasta")

# %%
input_dir = "phylogenomics/Proteins_renamed_r2"
output_dir = "phylogenomics/Proteins_renamed_r3"

rename_sequences(input_dir, output_dir)

# %%
! head -1 phylogenomics/Proteins_renamed_r3/NC_015789.mt_prots.fa
# Out:
# >NC_015789_COX1_1

# %% [markdown]
# Good.

# %% [markdown]
# Now we shall prepare to launch `Proteinortho`. `Proteinortho` has a lot of requirements for inputs. For instance, if in directory there are empty files - `Proteinortho` will just crash. So, we delete empty files!

# %%
for file in os.listdir("phylogenomics/Proteins_renamed_r3"):
    path = os.path.join("phylogenomics/Proteins_renamed_r3", file)
    if os.path.isfile(path) and os.path.getsize(path) == 0:
        os.remove(path)

# %% [markdown]
# Launch `Proteinortho`

# %%
! proteinortho phylogenomics/Proteins_renamed_r3/*.fa -cpus=10
# Out:
# *****************************************************************
# Proteinortho with PoFF version 6.3.4 - An orthology detection tool
# *****************************************************************
# Using 10 CPU threads (1 threads per processes each with 10 threads), Detected 'diamond' version 2.1.11
# Checking input files.
# Checking phylogenomics/Proteins_renamed_r3/NC_015789.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_015991.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_023125.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_023126.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_023127.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_023128.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_025200.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_027422.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_031375.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_033907.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_048507.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_051483.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_056146.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_056147.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_056148.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_056195.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_061762.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_069201.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_070174.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_071210.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_082275.mt_prots.fa... ok
# Checking phylogenomics/Proteins_renamed_r3/NC_082276.mt_prots.fa... ok
#
# **Step 1**
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_069201.mt_prots.fa'	(14 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_082276.mt_prots.fa'	(15 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_023128.mt_prots.fa'	(38 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_031375.mt_prots.fa'	(16 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_048507.mt_prots.fa'	(14 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_033907.mt_prots.fa'	(14 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_056195.mt_prots.fa'	(47 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_082275.mt_prots.fa'	(15 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_056146.mt_prots.fa'	(73 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_027422.mt_prots.fa'	(14 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_023127.mt_prots.fa'	(15 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_071210.mt_prots.fa'	(14 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_015789.mt_prots.fa'	(15 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_070174.mt_prots.fa'	(14 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_023125.mt_prots.fa'	(38 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_023126.mt_prots.fa'	(37 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_025200.mt_prots.fa'	(15 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_056147.mt_prots.fa'	(80 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_056148.mt_prots.fa'	(29 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_061762.mt_prots.fa'	(15 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_051483.mt_prots.fa'	(64 sequences)
# Generating indices.
# Building database for 'phylogenomics/Proteins_renamed_r3/NC_015991.mt_prots.fa'	(11 sequences)
#
# **Step 2** using diamond
# Running blast analysis: 100% (231/231)
# [OUTPUT] -> written to myproject.blast-graph
#
# **Step 3**
# Clustering by similarity (Proteinortho mode) using up to 16384 MB of memory (default value, command 'free' not found) and 10 cpu core(s). Please wait...
# Clustering using 10 threads
# Reading myproject.blast-graph
# 22 species
# 539 paired proteins
# 3368 bidirectional edges
# Clustering: working on (5@lapack* + 0@power) connected components
# [OUTPUT] -> Orthologous groups are written to myproject.proteinortho.tsv
# [OUTPUT] -> Orthologous pairs are written to myproject.proteinortho-graph
# # myproject.proteinortho.tsv statistics:
# # number of groups that contains at least p% species:
# # p	species	groups	genes in groups
# 0%	0	80 (100%)	539 (100%)
# 10%	2	80 (100%)	539 (100%)
# 20%	4	32 (40%)	417 (77.36%)
# 30%	6	25 (31.25%)	385 (71.42%)
# 40%	8	17 (21.25%)	324 (60.11%)
# 50%	11	15 (18.75%)	308 (57.14%)
# 60%	13	14 (17.5%)	297 (55.1%)
# 70%	15	14 (17.5%)	297 (55.1%)
# 80%	17	14 (17.5%)	297 (55.1%)
# 90%	19	14 (17.5%)	297 (55.1%)
# 100%	22	6 (7.5%)	132 (24.48%)
# # NOTE: p=100% correspond to the core proteome and p=0% to all groups
# # number of groups for each input species:
# NC_056147.mt_prots.fa	56	70%
# NC_056146.mt_prots.fa	50	62.5%
# NC_051483.mt_prots.fa	42	52.5%
# NC_056195.mt_prots.fa	40	50%
# NC_023128.mt_prots.fa	37	46.25%
# ...
# NC_048507.mt_prots.fa	14	17.5%
# NC_069201.mt_prots.fa	14	17.5%
# NC_070174.mt_prots.fa	14	17.5%
# NC_071210.mt_prots.fa	14	17.5%
# NC_015991.mt_prots.fa	10	12.5%
#
# [OUTPUT] -> Summary is written to myproject.proteinortho-graph.summary
# [OUTPUT] -> You can extract a html version of the output using:
# proteinortho2html.pl myproject.proteinortho.tsv [PLACE FASTA FILES HERE] >myproject.proteinortho.html
#
# [OUTPUT] -> You can extract an OrthoXML (v0.3) version of the orthology group output using:
# proteinortho2xml.pl myproject.proteinortho.tsv >myproject.proteinortho.tsv.xml
#
# All finished.

# %% [markdown]
# `Proteinortho` does not allow to redirect outputs, so we do it manually afterwards!

# %% [markdown]
# Create a directory to store `Proteinortho` outputs

# %%
! mkdir phylogenomics/protein_ortho_output/

# %% [markdown]
# Move `Proteinortho` outputs

# %%
! mv myproject* phylogenomics/protein_ortho_output/

# %% [markdown]
# Now let us work with `Proteinortho` output

# %% [markdown]
# Read the `phylogenomics/protein_ortho_output/myproject.proteinortho.tsv` file to `pandas` dataframe

# %%
df_all = pd.read_csv('phylogenomics/protein_ortho_output/myproject.proteinortho.tsv', sep='\t')

# %% [markdown]
# This is how it looks

# %%
df_all.head(15)
# Out:
# 10      NC_061762_NAD5_1      NC_069201_NAD5_1      NC_070174_NAD5_1
# 11      NC_061762_NAD3_1      NC_069201_NAD3_1      NC_070174_NAD3_1
# 12      NC_061762_COX1_1      NC_069201_COX1_1      NC_070174_COX1_1
# 13      NC_061762_rps3_1      NC_069201_rps3_1                     *
# 14      NC_061762_ATP9_1                     *      NC_070174_ATP9_1
#
#    NC_071210.mt_prots.fa NC_082275.mt_prots.fa NC_082276.mt_prots.fa
# 0       NC_071210_ATP6_1      NC_082275_ATP6_1      NC_082276_ATP6_1
# 1       NC_071210_COX2_1      NC_082275_COX2_1      NC_082276_COX2_1
# 2       NC_071210_COX3_1      NC_082275_COX3_1      NC_082276_COX3_1
# 3        NC_071210_COB_1       NC_082275_COB_1       NC_082276_COB_1
# 4       NC_071210_NAD1_1      NC_082275_NAD1_1      NC_082276_NAD1_1
# 5       NC_071210_NAD6_1      NC_082275_NAD6_1      NC_082276_NAD6_1
# 6       NC_071210_ATP8_1      NC_082275_ATP8_1      NC_082276_ATP8_1
# 7       NC_071210_NAD2_1      NC_082275_NAD2_1      NC_082276_NAD2_1
# 8       NC_071210_NAD4_2      NC_082275_NAD4_1      NC_082276_NAD4_1
# 9       NC_071210_NAD4_1      NC_082275_NAD4_2      NC_082276_NAD4_2
# 10      NC_071210_NAD5_1      NC_082275_NAD5_1      NC_082276_NAD5_1
# 11      NC_071210_NAD3_1      NC_082275_NAD3_1      NC_082276_NAD3_1
# 12      NC_071210_COX1_1      NC_082275_COX1_1      NC_082276_COX1_1
# 13      NC_071210_rps3_1      NC_082275_rps3_1      NC_082276_rps3_1
# 14                     *      NC_082275_ATP9_1      NC_082276_ATP9_1
#
# [15 rows x 25 columns]

# %% [markdown]
# We shall keep only the first 14 rows

# %%
df_all = df_all.iloc[:13]

# %%
df_all
# Out:
#     # Species  Genes  Alg.-Conn. NC_015789.mt_prots.fa NC_015991.mt_prots.fa  \
# 0          22     22       1.000      NC_015789_ATP6_1      NC_015991_ATP6_1
# 1          22     22       1.000      NC_015789_COX2_1      NC_015991_COX2_1
# 2          22     22       1.000      NC_015789_COX3_1      NC_015991_COX3_1
# 3          22     22       1.000      NC_015789_CYTB_1      NC_015991_CYTB_1
# 4          22     22       0.909      NC_015789_NAD1_1      NC_015991_NAD1_1
# 5          22     22       0.909      NC_015789_NAD6_1      NC_015991_NAD6_1
# 6          21     21       1.000      NC_015789_ATP8_1                     *
# 7          21     21       1.000      NC_015789_NAD2_1                     *
# 8          21     21       1.000      NC_015789_NAD4_1                     *
# 9          21     21       1.000      NC_015789_NAD4_2      NC_015991_NAD4_1
# 10         21     21       1.000      NC_015789_NAD5_1                     *
# 11         21     21       0.857      NC_015789_NAD3_1      NC_015991_NAD3_1
# 12         20     20       0.498      NC_015789_COX1_1                     *
#
#    NC_023125.mt_prots.fa NC_023126.mt_prots.fa NC_023127.mt_prots.fa  \
# 0       NC_023125_ATP6_1      NC_023126_ATP6_1      NC_023127_ATP6_1
# 8       NC_056147_NAD4_4      NC_056148_NAD4_2      NC_056195_NAD4_1
# 9       NC_056147_NAD4_1      NC_056148_NAD4_1                     *
# 10      NC_056147_NAD5_1      NC_056148_NAD5_1      NC_056195_NAD5_1
# 11      NC_056147_NAD3_1      NC_056148_NAD3_1      NC_056195_NAD3_1
# 12      NC_056147_COX1_1      NC_056148_COX1_1      NC_056195_COX1_1
#
#    NC_061762.mt_prots.fa NC_069201.mt_prots.fa NC_070174.mt_prots.fa  \
# 0       NC_061762_ATP6_1      NC_069201_ATP6_1      NC_070174_ATP6_1
# 1       NC_061762_COX2_1      NC_069201_COX2_1      NC_070174_COX2_1
# 2       NC_061762_COX3_1      NC_069201_COX3_1      NC_070174_COX3_1
# 3        NC_061762_COB_1       NC_069201_COB_1       NC_070174_COB_1
# 4       NC_061762_NAD1_1      NC_069201_NAD1_1      NC_070174_NAD1_1
# 5       NC_061762_NAD6_1      NC_069201_NAD6_1      NC_070174_NAD6_1
# 6       NC_061762_ATP8_1      NC_069201_ATP8_1      NC_070174_ATP8_1
# 7       NC_061762_NAD2_1      NC_069201_NAD2_1      NC_070174_NAD2_1
# 8       NC_061762_NAD4_1      NC_069201_NAD4_1      NC_070174_NAD4_1
# 9       NC_061762_NAD4_2      NC_069201_NAD4_2      NC_070174_NAD4_2
# 10      NC_061762_NAD5_1      NC_069201_NAD5_1      NC_070174_NAD5_1
# 11      NC_061762_NAD3_1      NC_069201_NAD3_1      NC_070174_NAD3_1
# 12      NC_061762_COX1_1      NC_069201_COX1_1      NC_070174_COX1_1
#
#    NC_071210.mt_prots.fa NC_082275.mt_prots.fa NC_082276.mt_prots.fa
# 0       NC_071210_ATP6_1      NC_082275_ATP6_1      NC_082276_ATP6_1
# 1       NC_071210_COX2_1      NC_082275_COX2_1      NC_082276_COX2_1
# 2       NC_071210_COX3_1      NC_082275_COX3_1      NC_082276_COX3_1
# 3        NC_071210_COB_1       NC_082275_COB_1       NC_082276_COB_1
# 4       NC_071210_NAD1_1      NC_082275_NAD1_1      NC_082276_NAD1_1
# 5       NC_071210_NAD6_1      NC_082275_NAD6_1      NC_082276_NAD6_1
# 6       NC_071210_ATP8_1      NC_082275_ATP8_1      NC_082276_ATP8_1
# 7       NC_071210_NAD2_1      NC_082275_NAD2_1      NC_082276_NAD2_1
# 8       NC_071210_NAD4_2      NC_082275_NAD4_1      NC_082276_NAD4_1
# 9       NC_071210_NAD4_1      NC_082275_NAD4_2      NC_082276_NAD4_2
# 10      NC_071210_NAD5_1      NC_082275_NAD5_1      NC_082276_NAD5_1
# 11      NC_071210_NAD3_1      NC_082275_NAD3_1      NC_082276_NAD3_1
# 12      NC_071210_COX1_1      NC_082275_COX1_1      NC_082276_COX1_1
#
# [13 rows x 25 columns]

# %% [markdown]
# Good.

# %% [markdown]
# If there are any non-single copy orthologs we must delete them!

# %%
df_all.loc[1] = df_all.loc[1].apply(lambda x: x.replace(',', '*') if isinstance(x, str) else x)

# %%
df_all
# Out:
#     # Species  Genes  Alg.-Conn. NC_015789.mt_prots.fa NC_015991.mt_prots.fa  \
# 0          22     22       1.000      NC_015789_ATP6_1      NC_015991_ATP6_1
# 1          22     22       1.000      NC_015789_COX2_1      NC_015991_COX2_1
# 2          22     22       1.000      NC_015789_COX3_1      NC_015991_COX3_1
# 3          22     22       1.000      NC_015789_CYTB_1      NC_015991_CYTB_1
# 4          22     22       0.909      NC_015789_NAD1_1      NC_015991_NAD1_1
# 5          22     22       0.909      NC_015789_NAD6_1      NC_015991_NAD6_1
# 6          21     21       1.000      NC_015789_ATP8_1                     *
# 7          21     21       1.000      NC_015789_NAD2_1                     *
# 8          21     21       1.000      NC_015789_NAD4_1                     *
# 9          21     21       1.000      NC_015789_NAD4_2      NC_015991_NAD4_1
# 10         21     21       1.000      NC_015789_NAD5_1                     *
# 11         21     21       0.857      NC_015789_NAD3_1      NC_015991_NAD3_1
# 12         20     20       0.498      NC_015789_COX1_1                     *
#
#    NC_023125.mt_prots.fa NC_023126.mt_prots.fa NC_023127.mt_prots.fa  \
# 0       NC_023125_ATP6_1      NC_023126_ATP6_1      NC_023127_ATP6_1
# 1       NC_023125_COX2_1      NC_023126_COX2_1      NC_023127_COX2_1
# 2       NC_023125_COX3_1      NC_023126_COX3_1      NC_023127_COX3_1
# 3        NC_023125_COB_1       NC_023126_COB_1       NC_023127_COB_1
# 4       NC_023125_NAD1_1      NC_023126_NAD1_1      NC_023127_NAD1_1
# 5       NC_023125_NAD6_1      NC_023126_NAD6_1      NC_023127_NAD6_1
# 6       NC_023125_ATP8_1      NC_023126_ATP8_1      NC_023127_ATP8_1
# 7       NC_023125_NAD2_1      NC_023126_NAD2_1      NC_023127_NAD2_1
# 8       NC_023125_NAD4_1      NC_023126_NAD4_1      NC_023127_NAD4_1
# 9       NC_023125_NAD4_2      NC_023126_NAD4_2      NC_023127_NAD4_2
# 10      NC_023125_NAD5_1      NC_023126_NAD5_1      NC_023127_NAD5_1
# 11      NC_023125_NAD3_1      NC_023126_NAD3_1      NC_023127_NAD3_1
# 12      NC_023125_COX1_1      NC_023126_COX1_1      NC_023127_COX1_1
#
#    NC_023128.mt_prots.fa NC_025200.mt_prots.fa  ... NC_056146.mt_prots.fa  \
# 0       NC_023128_ATP6_1      NC_025200_ATP6_1  ...      NC_056146_ATP6_1
# 1       NC_023128_COX2_1      NC_025200_COX2_1  ...      NC_056146_COX2_1
# 2       NC_023128_COX3_1      NC_025200_COX3_1  ...      NC_056146_COX3_1
# 3        NC_023128_COB_1       NC_025200_COB_1  ...       NC_056146_COB_1
# 4       NC_023128_NAD1_1      NC_025200_NAD1_1  ...      NC_056146_NAD1_1
# 5       NC_023128_NAD6_1      NC_025200_NAD6_1  ...      NC_056146_NAD6_1
# 6       NC_023128_ATP8_1      NC_025200_ATP8_1  ...      NC_056146_ATP8_1
# 7       NC_023128_NAD2_1      NC_025200_NAD2_1  ...      NC_056146_NAD2_1
# 1       NC_071210_COX2_1      NC_082275_COX2_1      NC_082276_COX2_1
# 2       NC_071210_COX3_1      NC_082275_COX3_1      NC_082276_COX3_1
# 3        NC_071210_COB_1       NC_082275_COB_1       NC_082276_COB_1
# 4       NC_071210_NAD1_1      NC_082275_NAD1_1      NC_082276_NAD1_1
# 5       NC_071210_NAD6_1      NC_082275_NAD6_1      NC_082276_NAD6_1
# 6       NC_071210_ATP8_1      NC_082275_ATP8_1      NC_082276_ATP8_1
# 7       NC_071210_NAD2_1      NC_082275_NAD2_1      NC_082276_NAD2_1
# 8       NC_071210_NAD4_2      NC_082275_NAD4_1      NC_082276_NAD4_1
# 9       NC_071210_NAD4_1      NC_082275_NAD4_2      NC_082276_NAD4_2
# 10      NC_071210_NAD5_1      NC_082275_NAD5_1      NC_082276_NAD5_1
# 11      NC_071210_NAD3_1      NC_082275_NAD3_1      NC_082276_NAD3_1
# 12      NC_071210_COX1_1      NC_082275_COX1_1      NC_082276_COX1_1
#
# [13 rows x 25 columns]

# %% [markdown]
# Good.

# %% [markdown]
# Now we shall drop every `*` from the dataset

# %%
df_all_cols_to_drop = df_all.columns[df_all.apply(lambda col: col.astype(str).str.contains(r'\*', regex=True).any())]

# %% [markdown]
# If we drop `NC_015991.mt_prots.fa`, `NC_051483.mt_prots.fa`, `NC_056195.mt_prots.fa` columns there will be no `*` in our data! Meaning there will be a set of 13 genes with exactly the same set of taxa (PERFECT!!!)

# %%
df_all_cols_to_drop
# Out:
# Index(['NC_015991.mt_prots.fa', 'NC_051483.mt_prots.fa',
#        'NC_056195.mt_prots.fa'],
#       dtype='object')

# %% [markdown]
# Drop'em and save the df to `phylogenomics/protein_ortho_output/All.tsv` file

# %%
df_all = df_all.drop(columns=df_all_cols_to_drop)
df_all.to_csv('phylogenomics/protein_ortho_output/All.tsv', sep='\t', index=False)

# %% [markdown]
# Now we shall start the process of extracting desired sequences

# %% [markdown]
# This script will write all the sequences families to be extracted

# %%
! Rscript scripts/write_family_names.R phylogenomics/protein_ortho_output/All.tsv phylogenomics/All/ phylogenomics/All_names/

# %% [markdown]
# By this step we create a huge dataset of all the sequences we've been analysing

# %%
! cat phylogenomics/Proteins_renamed_r3/*.fa > phylogenomics/all_pep.fa

# %% [markdown]
# Create a directory to store the desired sequences

# %%
! mkdir phylogenomics/All_seqs/

# %% [markdown]
# Now, using `BBMap` once again we will extract desired sequences from `Proteinortho` output!

# %%
# %%bash
#
# for file in phylogenomics/All_names/family*.txt
# do
#   bbmap/filterbyname.sh in=phylogenomics/all_pep.fa out=phylogenomics/All_seqs/$(basename "$file" .names.txt).seq.fa include=t names=$file overwrite=true ignorejunk=true
# done

# %% [markdown]
# Let us check the names of sequences in files

# %%
! head -1 phylogenomics/All_seqs/family1.seq.fa
# Out:
# >NC_015789_ATP6_1

# %% [markdown]
# Well, this is good. But for building the phylogenomic tree all the sequences in all the genes sets must be named the same! (e.g. not `>NC_015789_[GENE]`, but `>NC_015789`)

# %% [markdown]
# Create the directory to store the renamed sequences

# %%
! mkdir phylogenomics/All_seqs_renamed/

# %%
# %%bash
#
# for file in phylogenomics/All_seqs/*.fa
# do
#   # Process each file line by line
#   while read -r line; do
#     if [[ $line == \>* ]]; then
#       # For all other headers, delete the second "_" and everything after it
#       echo "$line" | sed 's/\(_[^_]*\)\(_.*\)/\1/' >> phylogenomics/All_seqs_renamed/$(basename "$file")
#     else
#       # For non-header lines (sequence data), copy them as-is
#       echo "$line" >> phylogenomics/All_seqs_renamed/$(basename "$file")
#     fi
#   done < "$file"
# done

# %%
! head -1 phylogenomics/All_seqs_renamed/family1.seq.fa
# Out:
# >NC_015789

# %% [markdown]
# Good.

# %% [markdown]
# Now we have everything ready for building phylogenomic tree!

# %% [markdown]
# Create the directory to store MSAs

# %%
# %%bash
#
# mkdir phylogenomics/MSAs/
# mkdir phylogenomics/MSAs/All/

# %% [markdown]
# Run `MAFFT`

# %%
! for file in phylogenomics/All_seqs_renamed/*.fa; do mafft --auto "$file" > phylogenomics/MSAs/All/$(basename "$file" .fa).aln; done
# Out:
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1- 274
# STEP 003-006-1  identical.
# Oscillating.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1- 104
# STEP 002-017-1  identical.
# Converged.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1-1083
# STEP 003-001-1  identical.    identical.    identical.    identical.
# Converged.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1- 178
# STEP 003-001-1  identical.
# Oscillating.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1-1300
# STEP 003-003-0  identical.    rejected. rejected. identical.
# Oscillating.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1- 253
# STEP 002-017-1  identical.
# Converged.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1- 272
# STEP 003-001-1  identical.    identical.
# Converged.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1- 401
# STEP 003-010-0  identical.    accepted.
# Converged.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1- 407
# STEP 003-006-0  identical.    identical.
# Converged.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1- 305
# STEP 002-005-1  identical.    identical.
# Converged.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1-  61
# STEP 002-017-1  identical.
# Converged.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1- 633
# STEP 003-005-0  identical.    identical.    identical.
# Converged.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8176 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.525
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    10 / 19
# done.
#
# Progressive alignment ...
# STEP    18 /18
# done.
# tbfast (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    10 / 19
# Segment   1/  1    1- 500
# STEP 002-003-1  identical.    identical.
# Converged.
#
# done
# dvtditr (aa) Version 7.525
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.

# %% [markdown]
# Create a directory to store trimmed MSAs

# %%
# %%bash
#
# mkdir phylogenomics/trimmed_MSAs/
# mkdir phylogenomics/trimmed_MSAs/All/

# %% [markdown]
# Run `trimAl`

# %%
! for file in phylogenomics/MSAs/All/*aln; do trimal -in $file -out phylogenomics/trimmed_MSAs/All/trimmed_$(basename "$file") -automated1; done

# %% [markdown]
# Create a directory to store `ModelFinder` data

# %%
# %%bash
#
# mkdir phylogenomics/model-finder/
# mkdir phylogenomics/model-finder/All/

# %% [markdown]
# Run `ModelFinder`

# %%
! iqtree2 -m MFP -s phylogenomics/trimmed_MSAs/All/ --prefix phylogenomics/model-finder/All/All -T AUTO
# Out:
# IQ-TREE multicore version 2.4.0 for MacOS Intel 64-bit built Feb 12 2025
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor, Heiko Schmidt,
# Dominik Schrempf, Michael Woodhams, Ly Trong Nhan, Thomas Wong
#
# Host:    Ilas-Mac-mini.local (SSE4.2, 16 GB RAM)
# Command: iqtree2 -m MFP -s phylogenomics/trimmed_MSAs/All/ --prefix phylogenomics/model-finder/All/All -T AUTO
# Seed:    594338 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Mon Mar 17 20:59:14 2025
# Kernel:  SSE2 - auto-detect threads (10 CPU cores detected)
#
# Reading 13 alignment files in directory phylogenomics/trimmed_MSAs/All/
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family1.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000638962 secs using 62.13% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 258 columns, 131 distinct patterns
# 73 parsimony-informative, 25 singleton sites, 160 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.40667e-05 secs using 568.7% CPU
#    1  NC_015789    0.39%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    1.16%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.39%    passed    100.00%
#    9  NC_033907   18.22%    passed     99.95%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.39%    passed    100.00%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.39%    passed    100.00%
#   16  NC_070174    0.00%    passed     99.95%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        1.10%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family10.seq.aln ... Fasta format detected
# Reading fasta file: done in 3.09944e-05 secs using 538.8% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 87 columns, 34 distinct patterns
# 9 parsimony-informative, 9 singleton sites, 69 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 5.00679e-06 secs using 359.5% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    0.00%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed    100.00%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.00%    passed    100.00%
#   16  NC_070174    0.00%    passed     99.96%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.00%  0 sequences failed composition chi2 test (p-value<5%; df=15)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family11.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000160217 secs using 904.4% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 653 columns, 233 distinct patterns
# 150 parsimony-informative, 60 singleton sites, 442 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.5974e-05 secs using 607.2% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    5.51%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.15%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed    100.00%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.15%    passed     99.99%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.31%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family12.seq.aln ... Fasta format detected
# Reading fasta file: done in 4.60148e-05 secs using 925.8% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 135 columns, 70 distinct patterns
# 44 parsimony-informative, 3 singleton sites, 88 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 9.05991e-06 secs using 883% CPU
#    1  NC_015789    0.00%    passed     99.96%
#    2  NC_023125    0.00%    passed     99.86%
#    3  NC_023126   12.59%    passed    100.00%
#    4  NC_023127   12.59%    passed    100.00%
#    5  NC_023128   12.59%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    7.41%    passed     99.97%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed     99.97%
#   12  NC_056147    0.00%    passed     99.97%
#   13  NC_056148    0.00%    passed     99.97%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.00%    passed     99.62%
#   16  NC_070174    0.00%    passed     99.99%
#   17  NC_071210    0.00%    passed     99.97%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        2.38%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family13.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000138044 secs using 909.9% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 526 columns, 138 distinct patterns
# 64 parsimony-informative, 40 singleton sites, 422 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 3.69549e-05 secs using 403.2% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125   11.03%    passed    100.00%
#    3  NC_023126   11.03%    passed    100.00%
#    4  NC_023127   11.03%    passed    100.00%
#    5  NC_023128   11.03%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.57%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    0.00%    passed    100.00%
#   10  NC_048507   11.03%    passed    100.00%
#   11  NC_056146    0.95%    passed    100.00%
#   12  NC_056147    0.95%    passed    100.00%
#   13  NC_056148    0.95%    passed    100.00%
#   14  NC_061762    0.19%    passed    100.00%
#   15  NC_069201    0.57%    passed    100.00%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.95%    passed    100.00%
#   18  NC_082275   11.03%    passed    100.00%
#   19  NC_082276   11.03%    passed    100.00%
# ****  TOTAL        4.33%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family2.seq.aln ... Fasta format detected
# Reading fasta file: done in 7.20024e-05 secs using 583.3% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 249 columns, 91 distinct patterns
# 57 parsimony-informative, 11 singleton sites, 181 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 7.15256e-06 secs using 461.4% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    7.23%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed    100.00%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.00%    passed    100.00%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.38%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family3.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.00014019 secs using 857.4% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 254 columns, 116 distinct patterns
# 68 parsimony-informative, 31 singleton sites, 155 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.00136e-05 secs using 519.3% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed     99.85%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    0.00%    passed    100.00%
#   10  NC_048507    0.00%    passed     99.35%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed    100.00%
#   14  NC_061762    0.00%    passed     99.97%
#   15  NC_069201    0.00%    passed    100.00%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed     98.76%
#   19  NC_082276    0.00%    passed     99.35%
# ****  TOTAL        0.00%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family4.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000103951 secs using 633% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 388 columns, 134 distinct patterns
# 81 parsimony-informative, 36 singleton sites, 271 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.3113e-05 secs using 533.8% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.52%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    0.52%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed    100.00%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.00%    passed    100.00%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.05%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family5.seq.aln ... Fasta format detected
# Reading fasta file: done in 8.98838e-05 secs using 672% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 360 columns, 162 distinct patterns
# 92 parsimony-informative, 46 singleton sites, 222 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 2.5034e-05 secs using 327.6% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed     99.95%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    1.67%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.28%    passed     99.98%
#   14  NC_061762    0.00%    passed     99.97%
#   15  NC_069201    0.00%    passed    100.00%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.10%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family6.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000145912 secs using 442.7% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 223 columns, 165 distinct patterns
# 128 parsimony-informative, 16 singleton sites, 79 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 3.60012e-05 secs using 430.5% CPU
#    1  NC_015789    0.00%    passed     99.44%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    1.79%    passed     98.88%
#    7  NC_027422    5.83%    passed     89.07%
#    8  NC_031375    2.24%    passed     99.89%
#    9  NC_033907   15.25%    passed     90.60%
#   10  NC_048507    2.24%    passed     99.66%
#   11  NC_056146    0.45%    passed     99.80%
#   12  NC_056147    0.45%    passed     99.80%
#   13  NC_056148    0.45%    passed     99.98%
#   14  NC_061762    1.35%    passed     94.09%
#   15  NC_069201   16.14%    passed     72.40%
#   16  NC_070174    2.69%    passed     97.40%
#   17  NC_071210    0.45%    passed     99.75%
#   18  NC_082275    2.24%    passed     99.05%
#   19  NC_082276    2.24%    passed     99.66%
# ****  TOTAL        2.83%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family7.seq.aln ... Fasta format detected
# Reading fasta file: done in 5.6982e-05 secs using 251% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 48 columns, 37 distinct patterns
# 15 parsimony-informative, 11 singleton sites, 22 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.00136e-05 secs using 639.1% CPU
#    1  NC_015789    0.00%    passed     99.99%
#    2  NC_023125    0.00%    passed     99.98%
#    3  NC_023126    0.00%    passed     99.98%
#    4  NC_023127    0.00%    passed     99.97%
#    5  NC_023128    0.00%    passed     99.98%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed     99.97%
#    9  NC_033907    0.00%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed     99.95%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.00%    passed     13.95%
#   16  NC_070174    0.00%    passed     99.97%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed     99.97%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.00%  0 sequences failed composition chi2 test (p-value<5%; df=14)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family8.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000272989 secs using 531.2% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 552 columns, 326 distinct patterns
# 231 parsimony-informative, 68 singleton sites, 253 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 2.59876e-05 secs using 423.3% CPU
#    1  NC_015789    0.00%    passed     99.75%
#    2  NC_023125    0.00%    passed     99.97%
#    3  NC_023126    0.00%    passed     99.97%
#    4  NC_023127    0.00%    passed     99.95%
#    5  NC_023128    0.00%    passed     99.97%
#    6  NC_025200    0.00%    passed     99.97%
#    7  NC_027422    0.00%    passed     99.53%
#    8  NC_031375    0.00%    passed     99.93%
#    9  NC_033907   22.46%    passed     94.84%
#   10  NC_048507    0.00%    passed     99.98%
#   11  NC_056146    0.00%    passed     99.47%
#   12  NC_056147    0.36%    passed     98.32%
#   13  NC_056148    0.18%    passed     98.04%
#   14  NC_061762    0.00%    passed     99.94%
#   15  NC_069201    0.36%    passed     85.13%
#   16  NC_070174   14.31%    passed     96.04%
#   17  NC_071210    0.36%    passed     98.54%
#   18  NC_082275    0.00%    passed     99.99%
#   19  NC_082276    0.00%    passed     99.98%
# ****  TOTAL        2.00%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family9.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000288963 secs using 366.5% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 489 columns, 214 distinct patterns
# 135 parsimony-informative, 58 singleton sites, 296 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 5.00679e-06 secs using 739% CPU
#    1  NC_015789    0.41%    passed    100.00%
#    2  NC_023125    0.41%    passed    100.00%
#    3  NC_023126    0.41%    passed    100.00%
#    4  NC_023127    0.41%    passed    100.00%
#    5  NC_023128    0.41%    passed    100.00%
#    6  NC_025200    0.00%    passed     99.65%
#    7  NC_027422    0.00%    passed     99.92%
#    8  NC_031375    0.41%    passed     99.98%
#    9  NC_033907   15.75%    passed     99.97%
#   10  NC_048507    0.00%    passed     99.99%
#   11  NC_056146    1.84%    passed     99.97%
#   12  NC_056147    1.84%    passed     99.97%
#   13  NC_056148    1.84%    passed     99.99%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.20%    passed     99.74%
#   16  NC_070174    0.00%    passed     99.99%
#   17  NC_071210    1.02%    passed     99.97%
#   18  NC_082275    0.00%    passed     99.99%
#   19  NC_082276    0.00%    passed     99.99%
# ****  TOTAL        1.31%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# NOTE: NC_082276 is identical to NC_048507 but kept for subsequent analysis
#
#
# Create initial parsimony tree by phylogenetic likelihood library (PLL)... 0.003 seconds
# Measuring multi-threading efficiency up to 10 CPU cores
# Increase to 10 rounds for branch lengths
# 33 trees examined
# Threads: 1 / Time: 10.101 sec / Speedup: 1.000 / Efficiency: 100% / LogL: -42480
# Threads: 2 / Time: 6.644 sec / Speedup: 1.520 / Efficiency: 76% / LogL: -42480
# Threads: 3 / Time: 4.671 sec / Speedup: 2.162 / Efficiency: 72% / LogL: -42480
# Threads: 4 / Time: 3.948 sec / Speedup: 2.558 / Efficiency: 64% / LogL: -42480
# Threads: 5 / Time: 3.971 sec / Speedup: 2.544 / Efficiency: 51% / LogL: -42480
# Threads: 6 / Time: 3.651 sec / Speedup: 2.767 / Efficiency: 46% / LogL: -42480
# BEST NUMBER OF THREADS: 4
#
# Perform fast likelihood tree search using LG+I+G model...
# Estimate model parameters (epsilon = 5.000)
# Perform nearest neighbor interchange...
# Estimate model parameters (epsilon = 1.000)
# 1. Initial log-likelihood: -33287.259
# Optimal log-likelihood: -33287.088
# Proportion of invariable sites: 0.323
# Gamma shape alpha: 0.527
# Parameters optimization took 1 rounds (0.047 sec)
# Time for fast ML tree search: 0.294 seconds
#
# NOTE: ModelFinder requires 42 MB RAM!
# ModelFinder will test up to 1232 protein models (sample size: 4222 epsilon: 0.100) ...
#  No. Model         -LnL         df  AIC          AICc         BIC
#   1  LG            35050.530    35  70171.060    70171.662    70393.242
#   2  LG+I          33684.321    36  67440.642    67441.278    67669.172
#   3  LG+G4         33340.418    36  66752.836    66753.472    66981.366
#   4  LG+I+G4       33286.443    37  66646.886    66647.558    66881.764
#   5  LG+R2         33340.621    37  66755.243    66755.915    66990.121
#   6  LG+R3         33223.817    39  66525.633    66526.379    66773.208
#   7  LG+R4         33222.255    41  66526.511    66527.334    66786.781
#  14  LG+I+R2       33239.608    38  66555.216    66555.925    66796.443
#  15  LG+I+R3       33220.753    40  66521.506    66522.291    66775.429
# 468  DCMut+F+R3    32651.306    58  65418.613    65420.257    65786.800
# 477  DCMut+F+I+R3  32647.654    59  65413.307    65415.008    65787.843
# 490  VT+R3         33355.948    39  66789.896    66790.642    67037.471
# 499  VT+I+R3       33355.825    40  66791.650    66792.435    67045.573
# 512  VT+F+R3       32615.382    58  65346.764    65348.408    65714.952
# 521  VT+F+I+R3     32613.435    59  65344.871    65346.572    65719.407
# 534  PMB+R3        33441.910    39  66961.819    66962.565    67209.394
# 543  PMB+I+R3      33441.221    40  66962.441    66963.226    67216.364
# 556  PMB+F+R3      32797.605    58  65711.209    65712.853    66079.397
# 565  PMB+F+I+R3    32794.764    59  65707.528    65709.229    66082.064
# 578  Blosum62+R3   33468.647    39  67015.295    67016.041    67262.869
# 587  Blosum62+I+R3 33468.589    40  67017.177    67017.962    67271.100
# 600  Blosum62+F+R3 32805.466    58  65726.933    65728.577    66095.121
# 609  Blosum62+F+I+R3 32803.072    59  65724.145    65725.846    66098.681
# 622  Dayhoff+R3    33847.178    39  67772.355    67773.101    68019.930
# 631  Dayhoff+I+R3  33844.114    40  67768.227    67769.012    68022.150
# 644  Dayhoff+F+R3  32649.281    58  65414.563    65416.207    65782.751
# 653  Dayhoff+F+I+R3 32645.514    59  65409.027    65410.728    65783.563
# 666  mtREV+R3      33150.438    39  66378.876    66379.622    66626.451
# 675  mtREV+I+R3    33143.283    40  66366.567    66367.351    66620.489
# 688  mtREV+F+R3    32577.114    58  65270.228    65271.872    65638.416
# 697  mtREV+F+I+R3  32568.916    59  65255.831    65257.532    65630.367
# 710  mtART+R3      32936.684    39  65951.367    65952.113    66198.942
# 719  mtART+I+R3    32926.311    40  65932.623    65933.407    66186.545
# 732  mtART+F+R3    32663.344    58  65442.688    65444.332    65810.875
# 741  mtART+F+I+R3  32650.742    59  65419.484    65421.185    65794.020
# 754  mtZOA+R3      32731.851    39  65541.701    65542.447    65789.276
# 763  mtZOA+I+R3    32725.298    40  65530.597    65531.381    65784.519
# 776  mtZOA+F+R3    32481.691    58  65079.381    65081.025    65447.569
# 785  mtZOA+F+I+R3  32473.224    59  65064.448    65066.149    65438.983
# 798  mtMet+R3      32864.669    39  65807.337    65808.083    66054.912
# 807  mtMet+I+R3    32858.712    40  65797.423    65798.208    66051.346
# 820  mtMet+F+R3    32520.178    58  65156.356    65158.000    65524.544
# 829  mtMet+F+I+R3  32513.657    59  65145.313    65147.014    65519.849
# 842  mtVer+R3      33346.702    39  66771.405    66772.151    67018.979
# 851  mtVer+I+R3    33339.690    40  66759.381    66760.165    67013.303
# 864  mtVer+F+R3    32763.087    58  65642.175    65643.819    66010.362
# 873  mtVer+F+I+R3  32752.777    59  65623.554    65625.255    65998.090
# 886  mtInv+R3      32947.396    39  65972.791    65973.538    66220.366
# 895  mtInv+I+R3    32942.177    40  65964.355    65965.139    66218.277
# 908  mtInv+F+R3    32427.382    58  64970.764    64972.408    65338.952
# 917  mtInv+F+I+R3  32423.137    59  64964.274    64965.975    65338.810
# 930  mtMAM+R3      33459.310    39  66996.620    66997.366    67244.194
# 939  mtMAM+I+R3    33446.230    40  66972.461    66973.245    67226.383
# 952  mtMAM+F+R3    32974.369    58  66064.738    66066.382    66432.926
# 961  mtMAM+F+I+R3  32954.134    59  66026.269    66027.970    66400.804
# WARNING: Normalizing state frequencies so that sum of them equals to 1
# 974  FLAVI+R3      33946.119    39  67970.237    67970.983    68217.812
# WARNING: Normalizing state frequencies so that sum of them equals to 1
# 983  FLAVI+I+R3    33935.788    40  67951.576    67952.361    68205.499
# WARNING: Normalizing state frequencies so that sum of them equals to 1
# 996  FLAVI+F+R3    33195.958    58  66507.915    66509.559    66876.103
# WARNING: Normalizing state frequencies so that sum of them equals to 1
# 1005  FLAVI+F+I+R3  33184.349    59  66486.699    66488.400    66861.235
# 1018  HIVb+R3       33764.738    39  67607.476    67608.222    67855.050
# 1027  HIVb+I+R3     33761.291    40  67602.582    67603.367    67856.505
# 1040  HIVb+F+R3     32836.620    58  65789.239    65790.883    66157.427
# 1049  HIVb+F+I+R3   32825.418    59  65768.837    65770.538    66143.372
# 1062  HIVw+R3       34561.034    39  69200.068    69200.814    69447.643
# 1071  HIVw+I+R3     34558.497    40  69196.994    69197.779    69450.917
# 1084  HIVw+F+R3     33357.531    58  66831.063    66832.707    67199.250
# 1093  HIVw+F+I+R3   33352.641    59  66823.283    66824.984    67197.819
# 1106  FLU+R3        33578.114    39  67234.228    67234.974    67481.802
# 1115  FLU+I+R3      33574.848    40  67229.695    67230.480    67483.618
# 1128  FLU+F+R3      32789.802    58  65695.603    65697.247    66063.791
# 1137  FLU+F+I+R3    32780.606    59  65679.212    65680.913    66053.747
# 1150  rtREV+R3      33754.582    39  67587.163    67587.909    67834.738
# 1159  rtREV+I+R3    33753.540    40  67587.080    67587.865    67841.003
# 1172  rtREV+F+R3    32736.382    58  65588.763    65590.407    65956.951
# 1181  rtREV+F+I+R3  32731.534    59  65581.069    65582.770    65955.605
# 1194  cpREV+R3      32952.198    39  65982.396    65983.142    66229.971
# 1203  cpREV+I+R3    32952.461    40  65984.923    65985.707    66238.845
# 1216  cpREV+F+R3    32411.668    58  64939.336    64940.980    65307.524
# 1225  cpREV+F+I+R3  32409.982    59  64937.964    64939.665    65312.500
# Akaike Information Criterion:           cpREV+F+I+R3
# Corrected Akaike Information Criterion: cpREV+F+I+R3
# Bayesian Information Criterion:         cpREV+F+R3
# Best-fit model: cpREV+F+R3 chosen according to BIC
#
# All model information printed to phylogenomics/model-finder/All/All.model.gz
# CPU time for ModelFinder: 222.113 seconds (0h:3m:42s)
# Wall-clock time for ModelFinder: 66.491 seconds (0h:1m:6s)
#
# NOTE: 12 MB RAM (0 GB) is required!
# Estimate model parameters (epsilon = 0.100)
# 1. Initial log-likelihood: -32411.674
# Optimal log-likelihood: -32411.659
# Site proportion and rates:  (0.674,0.123) (0.254,1.676) (0.071,6.875)
# Parameters optimization took 1 rounds (0.071 sec)
# Wrote distance file to...
# Computing ML distances based on estimated model parameters...
# Calculating distance matrix: done in 0.00537395 secs using 326.7% CPU
# Computing ML distances took 0.005479 sec (of wall-clock time) 0.017895 sec (of CPU time)
# Setting up auxiliary I and S matrices: done in 4.00543e-05 secs using 369.5% CPU
# Computing RapidNJ tree took 0.000415 sec (of wall-clock time) 0.001594 sec (of CPU time)
# Log-likelihood of RapidNJ tree: -32442.932
# --------------------------------------------------------------------
# |             INITIALIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Generating 98 parsimony trees... 0.233 second
# Computing log-likelihood of 98 initial trees ... 1.013 seconds
# Current best score: -32411.659
#
# Do NNI search on 20 best initial trees
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 1: -32411.654
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 2: -32388.810
# Iteration 10 / LogL: -32388.817 / Time: 0h:1m:9s
# Iteration 20 / LogL: -32388.914 / Time: 0h:1m:10s
# Finish initializing candidate tree set (2)
# Current best tree score: -32388.810 / CPU time: 4.318
# Number of iterations: 20
# --------------------------------------------------------------------
# |               OPTIMIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Iteration 30 / LogL: -32388.866 / Time: 0h:1m:12s (0h:0m:15s left)
# Iteration 40 / LogL: -32411.870 / Time: 0h:1m:14s (0h:0m:13s left)
# Iteration 50 / LogL: -32388.960 / Time: 0h:1m:16s (0h:0m:10s left)
# Iteration 60 / LogL: -32398.313 / Time: 0h:1m:18s (0h:0m:8s left)
# Iteration 70 / LogL: -32396.649 / Time: 0h:1m:20s (0h:0m:6s left)
# Iteration 80 / LogL: -32411.858 / Time: 0h:1m:21s (0h:0m:4s left)
# Iteration 90 / LogL: -32389.061 / Time: 0h:1m:23s (0h:0m:2s left)
# Iteration 100 / LogL: -32411.818 / Time: 0h:1m:25s (0h:0m:0s left)
# TREE SEARCH COMPLETED AFTER 103 ITERATIONS / Time: 0h:1m:26s
#
# --------------------------------------------------------------------
# |                    FINALIZING TREE SEARCH                        |
# --------------------------------------------------------------------
# Performs final model parameters optimization
# Estimate model parameters (epsilon = 0.010)
# 1. Initial log-likelihood: -32388.810
# 2. Current log-likelihood: -32388.798
# Optimal log-likelihood: -32388.793
# Site proportion and rates:  (0.676,0.124) (0.255,1.688) (0.069,6.995)
# Parameters optimization took 2 rounds (0.134 sec)
# BEST SCORE FOUND : -32388.793
# Total tree length: 1.217
#
# Total number of iterations: 103
# CPU time used for tree search: 76.530 sec (0h:1m:16s)
# Wall-clock time used for tree search: 19.584 sec (0h:0m:19s)
# Total CPU time used: 299.743 sec (0h:4m:59s)
# Total wall-clock time used: 86.348 sec (0h:1m:26s)
#
# Analysis results written to:
#   IQ-TREE report:                phylogenomics/model-finder/All/All.iqtree
#   Maximum-likelihood tree:       phylogenomics/model-finder/All/All.treefile
#   Likelihood distances:          phylogenomics/model-finder/All/All.mldist
#   Screen log file:               phylogenomics/model-finder/All/All.log
#
# Date and Time: Mon Mar 17 21:00:40 2025

# %% [markdown]
# Get the best substitution model!

# %%
! head -42 phylogenomics/model-finder/All/All.iqtree | tail -6
# Out:
# Best-fit model according to BIC: cpREV+F+R3
#
# List of models sorted by BIC scores:
#
# Model                  LogL         AIC      w-AIC        AICc     w-AICc         BIC      w-BIC
# cpREV+F+R3       -32411.668   64939.336 +    0.335   64940.980 +    0.341   65307.524 +    0.923

# %% [markdown]
# Create a directory to store final tree files

# %%
# %%bash
#
# mkdir phylogenomics/tree/
# mkdir phylogenomics/tree/All/

# %% [markdown]
# Run `IQ-TREE`

# %%
! iqtree2 -s phylogenomics/trimmed_MSAs/All/ -m cpREV+F+R3 --prefix phylogenomics/tree/All/All -bb 10000 -T AUTO
# Out:
# IQ-TREE multicore version 2.4.0 for MacOS Intel 64-bit built Feb 12 2025
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor, Heiko Schmidt,
# Dominik Schrempf, Michael Woodhams, Ly Trong Nhan, Thomas Wong
#
# Host:    Ilas-Mac-mini.local (SSE4.2, 16 GB RAM)
# Command: iqtree2 -s phylogenomics/trimmed_MSAs/All/ -m cpREV+F+R3 --prefix phylogenomics/tree/All/All -bb 10000 -T AUTO
# Seed:    404982 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Mon Mar 17 21:00:50 2025
# Kernel:  SSE2 - auto-detect threads (10 CPU cores detected)
#
# Reading 13 alignment files in directory phylogenomics/trimmed_MSAs/All/
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family1.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000556946 secs using 93.01% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 258 columns, 131 distinct patterns
# 73 parsimony-informative, 25 singleton sites, 160 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 3.69549e-05 secs using 416.7% CPU
#    1  NC_015789    0.39%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    1.16%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.39%    passed    100.00%
#    9  NC_033907   18.22%    passed     99.95%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.39%    passed    100.00%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.39%    passed    100.00%
#   16  NC_070174    0.00%    passed     99.95%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        1.10%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family10.seq.aln ... Fasta format detected
# Reading fasta file: done in 3.38554e-05 secs using 661.6% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 87 columns, 34 distinct patterns
# 9 parsimony-informative, 9 singleton sites, 69 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.09673e-05 secs using 838.9% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    0.00%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed    100.00%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.00%    passed    100.00%
#   16  NC_070174    0.00%    passed     99.96%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.00%  0 sequences failed composition chi2 test (p-value<5%; df=15)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family11.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000159979 secs using 450.7% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 653 columns, 233 distinct patterns
# 150 parsimony-informative, 60 singleton sites, 442 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 5.00679e-06 secs using 559.2% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    5.51%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.15%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed    100.00%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.15%    passed     99.99%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.31%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family12.seq.aln ... Fasta format detected
# Reading fasta file: done in 4.31538e-05 secs using 906.1% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 135 columns, 70 distinct patterns
# 44 parsimony-informative, 3 singleton sites, 88 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.09673e-05 secs using 866.2% CPU
#    1  NC_015789    0.00%    passed     99.96%
#    2  NC_023125    0.00%    passed     99.86%
#    3  NC_023126   12.59%    passed    100.00%
#    4  NC_023127   12.59%    passed    100.00%
#    5  NC_023128   12.59%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    7.41%    passed     99.97%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed     99.97%
#   12  NC_056147    0.00%    passed     99.97%
#   13  NC_056148    0.00%    passed     99.97%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.00%    passed     99.62%
#   16  NC_070174    0.00%    passed     99.99%
#   17  NC_071210    0.00%    passed     99.97%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        2.38%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family13.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000169992 secs using 504.7% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 526 columns, 138 distinct patterns
# 64 parsimony-informative, 40 singleton sites, 422 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.90735e-05 secs using 529.5% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125   11.03%    passed    100.00%
#    3  NC_023126   11.03%    passed    100.00%
#    4  NC_023127   11.03%    passed    100.00%
#    5  NC_023128   11.03%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.57%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    0.00%    passed    100.00%
#   10  NC_048507   11.03%    passed    100.00%
#   11  NC_056146    0.95%    passed    100.00%
#   12  NC_056147    0.95%    passed    100.00%
#   13  NC_056148    0.95%    passed    100.00%
#   14  NC_061762    0.19%    passed    100.00%
#   15  NC_069201    0.57%    passed    100.00%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.95%    passed    100.00%
#   18  NC_082275   11.03%    passed    100.00%
#   19  NC_082276   11.03%    passed    100.00%
# ****  TOTAL        4.33%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family2.seq.aln ... Fasta format detected
# Reading fasta file: done in 7.10487e-05 secs using 567.2% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 249 columns, 91 distinct patterns
# 57 parsimony-informative, 11 singleton sites, 181 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.3113e-05 secs using 648.2% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    7.23%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed    100.00%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.00%    passed    100.00%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.38%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family3.seq.aln ... Fasta format detected
# Reading fasta file: done in 7.10487e-05 secs using 914.9% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 254 columns, 116 distinct patterns
# 68 parsimony-informative, 31 singleton sites, 155 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 3.8147e-06 secs using 1022% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed     99.85%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    0.00%    passed    100.00%
#   10  NC_048507    0.00%    passed     99.35%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed    100.00%
#   14  NC_061762    0.00%    passed     99.97%
#   15  NC_069201    0.00%    passed    100.00%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed     98.76%
#   19  NC_082276    0.00%    passed     99.35%
# ****  TOTAL        0.00%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family4.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000103951 secs using 618.6% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 388 columns, 134 distinct patterns
# 81 parsimony-informative, 36 singleton sites, 271 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.69277e-05 secs using 762.1% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.52%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    0.52%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed    100.00%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.00%    passed    100.00%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.05%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family5.seq.aln ... Fasta format detected
# Reading fasta file: done in 8.89301e-05 secs using 833.2% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 360 columns, 162 distinct patterns
# 92 parsimony-informative, 46 singleton sites, 222 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.5974e-05 secs using 763.7% CPU
#    1  NC_015789    0.00%    passed    100.00%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    0.00%    passed     99.95%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed    100.00%
#    9  NC_033907    1.67%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.28%    passed     99.98%
#   14  NC_061762    0.00%    passed     99.97%
#   15  NC_069201    0.00%    passed    100.00%
#   16  NC_070174    0.00%    passed    100.00%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed    100.00%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.10%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family6.seq.aln ... Fasta format detected
# Reading fasta file: done in 6.91414e-05 secs using 666.7% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 223 columns, 165 distinct patterns
# 128 parsimony-informative, 16 singleton sites, 79 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.28746e-05 secs using 908.8% CPU
#    1  NC_015789    0.00%    passed     99.44%
#    2  NC_023125    0.00%    passed    100.00%
#    3  NC_023126    0.00%    passed    100.00%
#    4  NC_023127    0.00%    passed    100.00%
#    5  NC_023128    0.00%    passed    100.00%
#    6  NC_025200    1.79%    passed     98.88%
#    7  NC_027422    5.83%    passed     89.07%
#    8  NC_031375    2.24%    passed     99.89%
#    9  NC_033907   15.25%    passed     90.60%
#   10  NC_048507    2.24%    passed     99.66%
#   11  NC_056146    0.45%    passed     99.80%
#   12  NC_056147    0.45%    passed     99.80%
#   13  NC_056148    0.45%    passed     99.98%
#   14  NC_061762    1.35%    passed     94.09%
#   15  NC_069201   16.14%    passed     72.40%
#   16  NC_070174    2.69%    passed     97.40%
#   17  NC_071210    0.45%    passed     99.75%
#   18  NC_082275    2.24%    passed     99.05%
#   19  NC_082276    2.24%    passed     99.66%
# ****  TOTAL        2.83%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family7.seq.aln ... Fasta format detected
# Reading fasta file: done in 2.19345e-05 secs using 661.1% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 48 columns, 37 distinct patterns
# 15 parsimony-informative, 11 singleton sites, 22 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 3.8147e-06 secs using 104.9% CPU
#    1  NC_015789    0.00%    passed     99.99%
#    2  NC_023125    0.00%    passed     99.98%
#    3  NC_023126    0.00%    passed     99.98%
#    4  NC_023127    0.00%    passed     99.97%
#    5  NC_023128    0.00%    passed     99.98%
#    6  NC_025200    0.00%    passed    100.00%
#    7  NC_027422    0.00%    passed    100.00%
#    8  NC_031375    0.00%    passed     99.97%
#    9  NC_033907    0.00%    passed    100.00%
#   10  NC_048507    0.00%    passed    100.00%
#   11  NC_056146    0.00%    passed    100.00%
#   12  NC_056147    0.00%    passed    100.00%
#   13  NC_056148    0.00%    passed     99.95%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.00%    passed     13.95%
#   16  NC_070174    0.00%    passed     99.97%
#   17  NC_071210    0.00%    passed    100.00%
#   18  NC_082275    0.00%    passed     99.97%
#   19  NC_082276    0.00%    passed    100.00%
# ****  TOTAL        0.00%  0 sequences failed composition chi2 test (p-value<5%; df=14)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family8.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000141144 secs using 777.9% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 552 columns, 326 distinct patterns
# 231 parsimony-informative, 68 singleton sites, 253 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 2.09808e-05 secs using 572% CPU
#    1  NC_015789    0.00%    passed     99.75%
#    2  NC_023125    0.00%    passed     99.97%
#    3  NC_023126    0.00%    passed     99.97%
#    4  NC_023127    0.00%    passed     99.95%
#    5  NC_023128    0.00%    passed     99.97%
#    6  NC_025200    0.00%    passed     99.97%
#    7  NC_027422    0.00%    passed     99.53%
#    8  NC_031375    0.00%    passed     99.93%
#    9  NC_033907   22.46%    passed     94.84%
#   10  NC_048507    0.00%    passed     99.98%
#   11  NC_056146    0.00%    passed     99.47%
#   12  NC_056147    0.36%    passed     98.32%
#   13  NC_056148    0.18%    passed     98.04%
#   14  NC_061762    0.00%    passed     99.94%
#   15  NC_069201    0.36%    passed     85.13%
#   16  NC_070174   14.31%    passed     96.04%
#   17  NC_071210    0.36%    passed     98.54%
#   18  NC_082275    0.00%    passed     99.99%
#   19  NC_082276    0.00%    passed     99.98%
# ****  TOTAL        2.00%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# Reading alignment file phylogenomics/trimmed_MSAs/All/trimmed_family9.seq.aln ... Fasta format detected
# Reading fasta file: done in 0.000197887 secs using 499.3% CPU
# Alignment most likely contains protein sequences
# Alignment has 19 sequences with 489 columns, 214 distinct patterns
# 135 parsimony-informative, 58 singleton sites, 296 constant sites
#            Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 1.5974e-05 secs using 770% CPU
#    1  NC_015789    0.41%    passed    100.00%
#    2  NC_023125    0.41%    passed    100.00%
#    3  NC_023126    0.41%    passed    100.00%
#    4  NC_023127    0.41%    passed    100.00%
#    5  NC_023128    0.41%    passed    100.00%
#    6  NC_025200    0.00%    passed     99.65%
#    7  NC_027422    0.00%    passed     99.92%
#    8  NC_031375    0.41%    passed     99.98%
#    9  NC_033907   15.75%    passed     99.97%
#   10  NC_048507    0.00%    passed     99.99%
#   11  NC_056146    1.84%    passed     99.97%
#   12  NC_056147    1.84%    passed     99.97%
#   13  NC_056148    1.84%    passed     99.99%
#   14  NC_061762    0.00%    passed    100.00%
#   15  NC_069201    0.20%    passed     99.74%
#   16  NC_070174    0.00%    passed     99.99%
#   17  NC_071210    1.02%    passed     99.97%
#   18  NC_082275    0.00%    passed     99.99%
#   19  NC_082276    0.00%    passed     99.99%
# ****  TOTAL        1.31%  0 sequences failed composition chi2 test (p-value<5%; df=19)
# NOTE: NC_082276 is identical to NC_048507 but kept for subsequent analysis
#
# Create initial parsimony tree by phylogenetic likelihood library (PLL)... 0.002 seconds
# Generating 10000 samples for ultrafast bootstrap (seed: 404982)...
# WARNING: Default model LG may be under-fitting. Use option '-m TEST' to determine the best-fit model.
#
# NOTE: 60 MB RAM (0 GB) is required!
# Measuring multi-threading efficiency up to 10 CPU cores
# Increase to 10 rounds for branch lengths
# 187 trees examined
# Threads: 1 / Time: 10.017 sec / Speedup: 1.000 / Efficiency: 100% / LogL: -52425
# Threads: 2 / Time: 6.516 sec / Speedup: 1.537 / Efficiency: 77% / LogL: -52425
# Threads: 3 / Time: 4.784 sec / Speedup: 2.094 / Efficiency: 70% / LogL: -52425
# Threads: 4 / Time: 4.224 sec / Speedup: 2.372 / Efficiency: 59% / LogL: -52425
# Threads: 5 / Time: 4.299 sec / Speedup: 2.330 / Efficiency: 47% / LogL: -52425
# BEST NUMBER OF THREADS: 4
#
# Estimate model parameters (epsilon = 0.100)
# 1. Initial log-likelihood: -35153.225
# Optimal log-likelihood: -35050.531
# Parameters optimization took 1 rounds (0.010 sec)
# Wrote distance file to...
# Computing ML distances based on estimated model parameters...
# Calculating distance matrix: done in 0.00258183 secs using 444.9% CPU
# Computing ML distances took 0.002670 sec (of wall-clock time) 0.011778 sec (of CPU time)
# Setting up auxiliary I and S matrices: done in 4.19617e-05 secs using 395.6% CPU
# Computing RapidNJ tree took 0.000382 sec (of wall-clock time) 0.001508 sec (of CPU time)
# Log-likelihood of RapidNJ tree: -35129.284
# --------------------------------------------------------------------
# |             INITIALIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Generating 98 parsimony trees... 0.212 second
# Computing log-likelihood of 98 initial trees ... 0.371 seconds
# Current best score: -35050.531
#
# Do NNI search on 20 best initial trees
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 1: -35041.664
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 5: -35016.642
# Estimate model parameters (epsilon = 0.100)
# UPDATE BEST LOG-LIKELIHOOD: -35016.628
# Iteration 10 / LogL: -35041.664 / Time: 0h:0m:31s
# Iteration 20 / LogL: -35041.696 / Time: 0h:0m:33s
# Finish initializing candidate tree set (3)
# Current best tree score: -35016.628 / CPU time: 2.853
# Number of iterations: 20
# --------------------------------------------------------------------
# |               OPTIMIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Iteration 30 / LogL: -35016.631 / Time: 0h:0m:34s (0h:1m:28s left)
# Iteration 40 / LogL: -35016.630 / Time: 0h:0m:35s (0h:0m:58s left)
# Iteration 50 / LogL: -35791.456 / Time: 0h:0m:36s (0h:0m:40s left)
# Log-likelihood cutoff on original alignment: -35121.355
# Iteration 60 / LogL: -35041.663 / Time: 0h:0m:37s (0h:0m:28s left)
# Iteration 70 / LogL: -35041.665 / Time: 0h:0m:38s (0h:0m:19s left)
# Iteration 80 / LogL: -35041.665 / Time: 0h:0m:39s (0h:0m:12s left)
# Iteration 90 / LogL: -35168.634 / Time: 0h:0m:40s (0h:0m:6s left)
# Iteration 100 / LogL: -35041.664 / Time: 0h:0m:41s (0h:0m:2s left)
# Log-likelihood cutoff on original alignment: -35120.899
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 1.000
# TREE SEARCH COMPLETED AFTER 106 ITERATIONS / Time: 0h:0m:42s
#
# --------------------------------------------------------------------
# |                    FINALIZING TREE SEARCH                        |
# --------------------------------------------------------------------
# Performs final model parameters optimization
# Estimate model parameters (epsilon = 0.010)
# 1. Initial log-likelihood: -35016.628
# Optimal log-likelihood: -35016.628
# Parameters optimization took 1 rounds (0.014 sec)
# BEST SCORE FOUND : -35016.628
# Creating bootstrap support values...
# Split supports printed to NEXUS file phylogenomics/tree/All/All.splits.nex
# Total tree length: 0.961
#
# Total number of iterations: 106
# CPU time used for tree search: 45.043 sec (0h:0m:45s)
# Wall-clock time used for tree search: 11.920 sec (0h:0m:11s)
# Total CPU time used: 120.033 sec (0h:2m:0s)
# Total wall-clock time used: 42.417 sec (0h:0m:42s)
#
# Computing bootstrap consensus tree...
# Reading input file phylogenomics/tree/All/All.splits.nex...
# 19 taxa and 74 splits.
# Consensus tree written to phylogenomics/tree/All/All.contree
# Reading input trees file phylogenomics/tree/All/All.contree
# Log-likelihood of consensus tree: -35016.658
#
# Analysis results written to:
#   IQ-TREE report:                phylogenomics/tree/All/All.iqtree
#   Maximum-likelihood tree:       phylogenomics/tree/All/All.treefile
#   Likelihood distances:          phylogenomics/tree/All/All.mldist
#
# Ultrafast bootstrap approximation results written to:
#   Split support values:          phylogenomics/tree/All/All.splits.nex
#   Consensus tree:                phylogenomics/tree/All/All.contree
#   Screen log file:               phylogenomics/tree/All/All.log
#
# Date and Time: Mon Mar 17 21:01:32 2025

# %% [markdown]
# Now add `.1` to the accession numbers on the tree

# %%
def modify_tree_file(input_file, output_file):
    """
    Reads a Newick tree from a file, adds ".1" to all accession numbers, 
    and writes the modified tree to an output file.

    Args:
        input_file (str): Path to the input tree file.
        output_file (str): Path to save the modified tree.
    """

    def add_suffix(match):
        return match.group(0) + ".1"

    # Read tree from file
    with open(input_file, "r") as infile:
        tree_str = infile.read().strip()

    # Modify tree
    modified_tree = re.sub(r'NC_\d+', add_suffix, tree_str)

    # Write modified tree to output file
    with open(output_file, "w") as outfile:
        outfile.write(modified_tree)

    print(f"Modified tree saved to: {output_file}")

# %%
input_tree_file = "phylogenomics/tree/All/All.treefile"  # Replace with actual file path
output_tree_file = "phylogenomics/tree/All/All_ready.treefile"

modify_tree_file(input_tree_file, output_tree_file)
# Out:
# Modified tree saved to: phylogenomics/tree/All/All_ready.treefile

# %% [markdown]
# Now please proceed to the `04_ggtree_journal.R` to visualize the phylogenetic trees
